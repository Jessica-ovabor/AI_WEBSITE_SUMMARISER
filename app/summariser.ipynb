# %% [markdown]
# This Notebook is Specific to a particular website

# %% [markdown]
# # Define imports and dependencise

# %%
from openai import OpenAI
from dotenv import load_dotenv
from scraper import web_scraper
import os
import openai


load_dotenv()

api_key = os.getenv("OPENROUTER_API_KEY")
website_url = os.getenv("WEBSITE_URL")

if not api_key:
    print("Error: OPENROUTER_API_KEY not found in environment variables")
    exit(1)

# %% [markdown]
# # Define Open AI client library for open source frontier models

# %%
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
)

# %% [markdown]
# # Define system and user prompt

# %%
system_prompt = "You are an skillful AI assitant who is skilled in summarising any content. You provide short and concise summarisation while keeping all the main point intact. The content you provide is meaningful and well structured"

user_prompt = web_scraper(website_url)

print(user_prompt)
# Out:
# ['Logistics and Supply Chain Management\nCheck match\nM.Sc. / Part-time / Online\n14,940,400 NGN / year\n2 years\nEmbry-Riddle Aeronautical University\n2.7(3)\nOnline\nRanked top\n8%\nView Programme Information\nFeatured', 'Nursing\nCheck match\nM.Sc. / Full-time, Part-time / On Campus\n34,576,836 NGN / year\n1 year\nThe University of Lancashire\n4(56)\nPreston, England, United Kingdom\nRanked top\n5%\nView Programme Information\nFeatured', 'Cyber Security and Forensics\nCheck match\nM.Sc. / Full-time, Part-time / On Campus\n33,804,169 NGN / year\n1 year\nUniversity of Westminster\n4.3(122)\nLondon, England, United Kingdom\nRanked top\n6%\nView Programme Information\nFeatured']

# %% [markdown]
# # Send request to models on OpenRouter AI

# %%
try:
    response = client.chat.completions.create(
        model="openai/gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content": f"Hello, Can you sumarise the content of this {user_prompt}"
            }
        ],
        extra_body={"reasoning": {"enabled": True}}


    )
    print(response.choices[0].message.content)
    
except openai.AuthenticationError as e:
    print(f"Authentication failed: {e}")
except openai.RateLimitError as e:
    print(f"Rate limit exceeded: {e}")
except openai.APIConnectionError as e:
    print(f"Connection error: {e}")
except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# 1. Logistics and Supply Chain Management M.Sc. program at Embry-Riddle Aeronautical University is part-time, online, 2 years long, with a tuition of 14,940,400 NGN per year. The program is ranked among the top with 8% acceptance rate.
#
# 2. Nursing M.Sc. program at The University of Lancashire is available full-time or part-time on campus for 1 year, with a tuition of 34,576,836 NGN per year. Ranked in the top 5%, the program is located in Preston, England, United Kingdom.
#
# 3. Cyber Security and Forensics M.Sc. program at the University of Westminster is offered full-time or part-time on campus for 1 year, with a tuition of 33,804,169 NGN per year. The program, located in London, England, United Kingdom, is also ranked in the top 6%.
